# %% [markdown]
# # Plasma_Example_1 — 束驱动等离子体尾场
#
# 本 notebook 是官方算例系列示例之一 (全部位于 examples/ 目录): 只跑这一个官方算例, 逐步解读输入卡、展示本算例最有代表性的图。

# %%
# %run ../notebooks/_bootstrap.py
# Out:
# astra-notebook 后端已加载 (v0.1.0)
# 项目根目录: /Users/yuxinwu/my_projects/astra_notebook
# 模拟工作目录: /Users/yuxinwu/my_projects/astra_notebook/data/workspace
# ASTRA    : /Users/yuxinwu/programs/ASTRA/astra
# Generator: /Users/yuxinwu/programs/ASTRA/generator

# %%
# ===== 共享规格 (单一数据源, 与 06 汇总一致) =====
from examples._examples_spec import (
    EXAMPLES, run_example, phase_files, compare_xemit)
NAME = "Plasma_Example_1"
STEM = "plasma"
print("算例:", NAME, "| 物理:", EXAMPLES[NAME]["title"])
# Out:
# 算例: Plasma_Example_1 | 物理: 束驱动等离子体尾场

# %%
# ===== 运行本算例 (generator/astra 按需) =====
work = run_example(NAME)
print("输出文件:")
for f in sorted(work.glob(STEM + ".*")):
    print("  ", f.name)
# Out:
#  --------------------------------------------------------------------------
#
#                               generator
#                Version 1.0 - macOS 64bit - Apple Silicon
#                         DESY,  Hamburg 2002
#                         Tue Aug 18 00:10:58
#
#      Working File is:    phsp.in
#      Initializing       1000      electrons
#      including 6 probe particles at standard positions
#      Particles are quasi randomly distributed
#
#      Final check:
#      Particles taken into account      N =       1000
#      total charge                      Q =    -1.0000E-04 nC
#      horizontal beam position          x =     1.7439E-07 mm
#      vertical beam position            y =     1.5831E-08 mm
#      longitudinal beam position        z =     3.0448E-11 m
#      horizontal beam size          sig x =     1.5786E-03 mm
#      vertical beam size            sig y =     1.5796E-03 mm
#      longitudinal beam size        sig z =     9.8772E-04 mm
#      total emission time               t =     1.9666E-05 ns
#      rms emission time             sig t =      0.000     ns
#      average kinetic energy            E =      100.0     MeV
#      energy spread                    dE =      98.50     keV
#      average momentum                  P =      100.5     MeV/c
#      transverse beam emittance     eps x =     9.6175E-02 pi mrad mm
#      correlated divergence         cor x =    -0.3898     mrad
#      transverse beam emittance     eps y =     9.5643E-02 pi mrad mm
#      correlated divergence         cor y =    -0.3901     mrad
#      longitudinal beam emittance   eps z =     9.7295E-02 pi keV mm
#      correlated energy spread      cor z =    -0.2819     keV
#      emittance ratio eps y/eps x         =      1.006
#
#      phase-space distribution saved to file: phsp.ini
#
#  --------------------------------------------------------------------------
#
#                      Astra- A space charge tracking algorithm
#                Version 4.0 - macOS 64bit - OpenMPI - Apple Silicon
#                               DESY,  Hamburg 2022
#                          18. 8.2026   0:10
#
#      Parameter file is:  plasma.in
#
#
#  Initialize element settings:
#      neglecting space charge forces
#
#  --------------------------------------------------------------------------
#  Cavity:
#
#      Reading cavity field data from:      PLASMA_flattop.txt
#      Cavity Frequency               f =    0.000     GHz
#      Plasma density                 n =   1.0000E+17 cm^-3
#      Plasma periode                       1.0559E-04 m
#      Plasma starts at                     2.4000E-03 m
#      Plasma ends at                       1.2400E-02 m
#      Max E-field                           4319.     MV/m
#      nominal phase                         0.000     deg
#
#  --------------------------------------------------------------------------
#     1000 particles from file phsp.ini
#
#      Particles taken into account      N =       1000
#      total charge                      Q =    -1.0000E-04 nC
#      horizontal beam position          x =     1.7442E-07 mm
#      vertical beam position            y =     1.6082E-08 mm
#      longitudinal beam position        z =     3.0226E-11 m
#      horizontal beam size          sig x =     1.5786E-03 mm
#      vertical beam size            sig y =     1.5796E-03 mm
#      longitudinal beam size        sig z =     9.8772E-04 mm
#      average kinetic energy            E =      100.0     MeV
#      energy spread                    dE =      98.50     keV
#      average momentum                  P =      100.5     MeV/c
#      transverse beam emittance     eps x =     9.6175E-02 pi mrad mm
#      correlated divergence         cor x =    -0.3898     mrad
#      transverse beam emittance     eps y =     9.5643E-02 pi mrad mm
#      correlated divergence         cor y =    -0.3901     mrad
#      longitudinal beam emittance   eps z =     9.7295E-02 pi keV mm
#      correlated energy spread      cor z =    -0.2819     keV
#      emittance ratio eps y/eps x         =      1.006
#  --------------------------------------------------------------------------
#  on axis tracking of the reference particle:
#      initial position                  z =    0.000     m
#                                        x =    0.000     mm
#                                        y =    0.000     mm
#      initial momentum                  p =    100.5     MeV/c
#      global phase shift              phi =    0.000     deg
#      time step for integration        dt =   0.1000     ps
#  --------------------------------------------------------------------------
#  Online element settings:
#
#  --------------------------------------------------------------------------
#
#      particle reaches position         z =   1.5000E-02 m
#      time of flight is                 t =   5.0035E-02 ns
#      final momentum                    p =    134.1     MeV/c
#      final phase (cavity 1)      phi_end =   0.5016     deg
#  --------------------------------------------------------------------------
#  off axis tracking of the reference particle:
#      initial position                  z =    0.000     m
#                                        x =   1.5786E-03 mm
#                                        y =   1.5796E-03 mm
#
#      final position                    x =   1.7555E-03 mm
#                                        y =   1.7565E-03 mm
#      divergence                    px/pz =   0.1169     mrad
#                                    py/pz =   0.1169     mrad
#  --------------------------------------------------------------------------
#  tracking of     1000 particles :
#      tracking will stop at             z =   1.5000E-02 m
#
#      space charge forces are EXCLUDED
#
#      working ...
#
#
#      final checkpoint at               z =   1.5000E-02 m
#      total number of iteration steps:           600
#
#      **********************************************************************
#
#      Particles taken into account      N =       1000
#      total charge                      Q =    -1.0000E-04 nC
#      horizontal beam position          x =     3.9792E-06 mm
#      vertical beam position            y =     5.3285E-06 mm
#      longitudinal beam position        z =     1.5000E-02 m
#      horizontal beam size          sig x =     1.4554E-03 mm
#      vertical beam size            sig y =     1.4372E-03 mm
#      longitudinal beam size        sig z =     9.8658E-04 mm
#      average kinetic energy            E =      133.5     MeV
#      energy spread                    dE =      1030.     keV
#      average momentum                  P =      134.0     MeV/c
#      transverse beam emittance     eps x =     9.6382E-02 pi mrad mm
#      correlated divergence         cor x =     0.3250     mrad
#      transverse beam emittance     eps y =     9.5800E-02 pi mrad mm
#      correlated divergence         cor y =     0.3224     mrad
#      longitudinal beam emittance   eps z =     0.1260     pi keV mm
#      correlated energy spread      cor z =     -1022.     keV
#      emittance ratio eps y/eps x         =      1.006
#
#      Particle Statistics:
#
#
#      Total number of particles on stack     =       1000
#      Electrons (total)                      =       1000
#      particles at the cathode               =          0
#      active particles                       =       1000
#      passive particles (lost out of bunch)  =          0
#      probe particles                        =          6
#      backward traveling particles           =          0
#      particles lost with z<Zmin             =          0
#      particles lost due to cathode field    =          0
#      particles lost on aperture             =          0
#
#      **********************************************************************
#
#      Emittance information saved to file    : plasma.Xemit.001
#      Emittance information saved to file    : plasma.Yemit.001
#      Emittance information saved to file    : plasma.Zemit.001
#      Trajectories saved to file             : plasma.track.001
#      Phase-space distributions logged in    : plasma.Log.001
#
#      **********************************************************************
#
#
#      finished simulation  18. 8.2026      0:10
#      execution time:  0.20 sek
#      Goodbye.
#  --------------------------------------------------------------------------
# Note: The following floating-point exceptions are signalling: IEEE_OVERFLOW_FLAG
# 输出文件:
#    plasma.0001.001
#    plasma.Log.001
#    plasma.Xemit.001
#    plasma.Yemit.001
#    plasma.Zemit.001
#    plasma.in
#    plasma.track.001

# %%
# ===== 束团统计 (最后一个 z 位置) =====
from astra_tools.io import read_distribution
from astra_tools.analysis.statistics import compute_statistics, print_statistics
from astra_tools.widgets.panels import stats_table_html
ph = phase_files(work, STEM)
dist = read_distribution(ph[-1])
print("相空间文件:", ph[-1].name)
print_statistics(compute_statistics(dist),
                 title="%s @ %s" % (NAME, ph[-1].name))
stats_table_html(compute_statistics(dist))
# Out:
# 相空间文件: plasma.0001.001
#
# ================================================================
#   Plasma_Example_1 @ plasma.0001.001
# ================================================================
#   Particles:           1000 total,     1000 active,      0 passive,
#                          0 lost,      0 not started
#   Total charge:        0.0001 nC (|Q| shown; sign kept internally)
# ----------------------------------------
#   Ref. momentum:     134.0773 MeV/c
#   Ref. kinetic E:    133.5673 MeV
#   gamma:             262.3847
#   beta:              0.999993
# ----------------------------------------
#   Centroid x:          0.0000 mm
#   Centroid y:          0.0000 mm
#   Centroid z:         15.0000 mm
#   sigma_x:             0.0015 mm
#   sigma_y:             0.0014 mm
#   sigma_z:             0.0010 mm
# ----------------------------------------
#   Mean pz:           133.9883 MeV/c
#   sigma_p/p:         0.007689
#   Mean E_kin:        133.4782 MeV
#   sigma_E:          1030.2805 keV
#   sigma_E/E:         0.007719
# ----------------------------------------
#   eps_x (geom):        0.0004 um.rad
#   eps_y (geom):        0.0004 um.rad
#   eps_nx:              0.0964 um.rad (= 0.0964 mm.mrad)
#   eps_ny:              0.0958 um.rad (= 0.0958 mm.mrad)
# ----------------------------------------
#   beta_x / alpha_x / gamma_T:   0.0058 m /  -1.2866 / 460.5257 1/m
#   beta_y / alpha_y / gamma_T:   0.0057 m /  -1.2681 / 461.0049 1/m
# ================================================================
# <table style='border-collapse:collapse;font-family:monospace'><tr><th>quantity</th><th>value</th><th>unit</th></tr><tr><td>n_particle</td><td align='right'>1000</td><td></td></tr>
# <tr><td>n_active</td><td align='right'>1000</td><td></td></tr>
# <tr><td>n_passive</td><td align='right'>0</td><td></td></tr>
# <tr><td>n_lost</td><td align='right'>0</td><td></td></tr>
# <tr><td>n_not_started</td><td align='right'>0</td><td></td></tr>
# <tr><td>total_charge_nC</td><td align='right'>0.0001 (|Q|)</td><td>nC</td></tr>
# <tr><td>mean_x_mm</td><td align='right'>3.97918e-06</td><td>mm</td></tr>
# <tr><td>mean_y_mm</td><td align='right'>5.32849e-06</td><td>mm</td></tr>
# <tr><td>mean_z_mm</td><td align='right'>15</td><td>mm</td></tr>
# <tr><td>sig_x_mm</td><td align='right'>0.00145535</td><td>mm</td></tr>
# <tr><td>sig_y_mm</td><td align='right'>0.00143725</td><td>mm</td></tr>
# <tr><td>sig_z_mm</td><td align='right'>0.000986578</td><td>mm</td></tr>
# <tr><td>mean_pz_MeVc</td><td align='right'>133.988</td><td>MeV/c</td></tr>
# <tr><td>sig_p_over_p_pct</td><td align='right'>0.768939</td><td>%</td></tr>
# <tr><td>mean_E_kin_MeV</td><td align='right'>133.478</td><td>MeV</td></tr>
# <tr><td>sig_E_keV</td><td align='right'>1030.28</td><td>keV</td></tr>
# <tr><td>sig_E_over_E_pct</td><td align='right'>0.771872</td><td>%</td></tr>
# <tr><td>emit_z_keV_mm</td><td align='right'>0.126034</td><td></td></tr>
# <tr><td>sig_xp_mrad</td><td align='right'>0.4113</td><td>mrad</td></tr>
# <tr><td>sig_yp_mrad</td><td align='right'>0.41027</td><td>mrad</td></tr>
# <tr><td>emit_x_geom_um</td><td align='right'>0.000367337</td><td>um.rad</td></tr>
# <tr><td>emit_y_geom_um</td><td align='right'>0.000365118</td><td>um.rad</td></tr>
# <tr><td>emit_x_norm_um</td><td align='right'>0.0963828</td><td>um.rad</td></tr>
# <tr><td>emit_y_norm_um</td><td align='right'>0.0958008</td><td>um.rad</td></tr>
# <tr><td>emit_x_norm_mm_mrad</td><td align='right'>0.0963828</td><td>mm.mrad</td></tr>
# <tr><td>emit_y_norm_mm_mrad</td><td align='right'>0.0958008</td><td>mm.mrad</td></tr>
# <tr><td>beta_x_m</td><td align='right'>0.00576598</td><td>m</td></tr>
# <tr><td>alpha_x</td><td align='right'>-1.28662</td><td>1</td></tr>
# <tr><td>gamma_t_x</td><td align='right'>460.526</td><td>1/m</td></tr>
# <tr><td>beta_y_m</td><td align='right'>0.00565756</td><td>m</td></tr>
# <tr><td>alpha_y</td><td align='right'>-1.26813</td><td>1</td></tr>
# <tr><td>gamma_t_y</td><td align='right'>461.005</td><td>1/m</td></tr>
# <tr><td>ref_momentum_MeVc</td><td align='right'>134.077</td><td>MeV/c</td></tr>
# <tr><td>ref_kinetic_energy_MeV</td><td align='right'>133.567</td><td>MeV</td></tr>
# <tr><td>gamma</td><td align='right'>262.385</td><td>1</td></tr>
# <tr><td>beta_rel</td><td align='right'>0.999993</td><td>1</td></tr></table>

# %% [markdown]
# ### 示例要点
#
# File_Efield=PLASMA... 触发尾场模块; PLASMA_flattop.txt 是密度剖面 (任意单位, 归一化到 P_n)。展示剖面与能量演化。

# %%
from astra_tools.plot.advanced_plots import plot_plasma_profile
plot_plasma_profile(work / "PLASMA_flattop.txt", peak_density_cm3=1e17)

# %%
from astra_tools.io.astra_emit import read_emit_files
from astra_tools.plot.emit_plots import (
    plot_energy_evolution, plot_emittance_evolution)
emit = read_emit_files(str(work / STEM))
plot_energy_evolution(emit)
plot_emittance_evolution(emit)

# %%
from astra_tools.plot.phase_space import plot_phase_space
plot_phase_space(dist, plane="z")

# %%
# ===== 黄金比对 (rel < 0.5% 判 OK) =====
compare_xemit(NAME, work)
print("其他官方算例的示例 notebook 同样位于 examples/ 目录")
# Out:
#   末行比对 (new vs golden):
#     norm_emit_x    9.6382e-08 9.6382e-08 rel=0.0000% OK
#     sigma_x        1.4554e-06 1.4554e-06 rel=0.0000% OK
#     mean_z         0.015      0.015      rel=0.0000% OK
# 其他官方算例的示例 notebook 同样位于 examples/ 目录
