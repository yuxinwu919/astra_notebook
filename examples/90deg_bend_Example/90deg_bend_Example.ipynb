# %% [markdown]
# # 90deg_bend_Example — 90° 弯转: 3D 二极场, 分段追踪
#
# 本 notebook 是 06 汇总 (notebooks/06_examples.ipynb) 的细分教学: 只跑这一个官方算例, 逐步解读输入卡、展示本算例最有代表性的图。

# %%
# %run ../../notebooks/_bootstrap.py
# Out:
# astra-notebook 后端已加载 (v0.1.0)
# 项目根目录: /Users/yuxinwu/my_projects/astra_notebook
# 模拟工作目录: /Users/yuxinwu/my_projects/astra_notebook/data/workspace
# ASTRA    : /Users/yuxinwu/programs/ASTRA/astra
# Generator: /Users/yuxinwu/programs/ASTRA/generator

# %%
# ===== 共享规格 (单一数据源, 与 06 汇总一致) =====
from examples._examples_spec import (
    EXAMPLES, run_example, phase_files, compare_xemit)
NAME = "90deg_bend_Example"
STEM = "Section1"
print("算例:", NAME, "| 物理:", EXAMPLES[NAME]["title"])
# Out:
# 算例: 90deg_bend_Example | 物理: 90° 弯转: 3D 二极场, 分段追踪

# %%
# ===== 运行本算例 (generator/astra 按需) =====
work = run_example(NAME)
print("输出文件:")
for f in sorted(work.glob(STEM + ".*")):
    print("  ", f.name)
# Out:
#  --------------------------------------------------------------------------
#
#                      Astra- A space charge tracking algorithm
#                Version 4.0 - macOS 64bit - OpenMPI - Apple Silicon
#                               DESY,  Hamburg 2022
#                          15. 8.2026  21:45
#
#      Parameter file is:  Section1.in
#      90 degree bend section 1
#
#  Initialize element settings:
#      neglecting space charge forces
#
#  --------------------------------------------------------------------------
#  Cavity:
#
#      Reading cavity field data from:      3D_Dipole
#      Cavity Frequency               f =    0.000     GHz
#      3D magnetic field length             0.4500     m
#      Number of periods                      1
#      3D Section starts at                -0.3000     m
#      3D Section ends at                   0.1500     m
#      maximum By field                     6.0312E-02 T
#      at                                   2.0000E-02 m
#
#
#           WARNING: Switch to relative file name convention
#
#  --------------------------------------------------------------------------
#        7 particles from file test.ini
#
#      Particles taken into account      N =          7
#      total charge                      Q =    -7.0000E-02 nC
#      horizontal beam position          x =      0.000     mm
#      vertical beam position            y =      0.000     mm
#      longitudinal beam position        z =     -1.000     m
#      horizontal beam size          sig x =      0.000     mm
#      vertical beam size            sig y =      0.000     mm
#      longitudinal beam size        sig z =      0.000     mm
#      average kinetic energy            E =      3.497     MeV
#      energy spread                    dE =      21.18     keV
#      average momentum                  P =      3.975     MeV/c
#      transverse beam emittance     eps x =      0.000     pi mrad mm
#      correlated divergence         cor x =      0.000     mrad
#      transverse beam emittance     eps y =      0.000     pi mrad mm
#      correlated divergence         cor y =      0.000     mrad
#      longitudinal beam emittance   eps z =      0.000     pi keV mm
#      correlated energy spread      cor z =      0.000     keV
#      emittance ratio eps y/eps x         =      0.000
#  --------------------------------------------------------------------------
#  on axis tracking of the reference particle:
#      initial position                  z =   -1.000     m
#                                        x =    0.000     mm
#                                        y =    0.000     mm
#      initial momentum                  p =    3.975     MeV/c
#      global phase shift              phi =    0.000     deg
#      time step for integration        dt =   0.3000     ps
#  --------------------------------------------------------------------------
#  Online element settings:
#
#  --------------------------------------------------------------------------
#
#      particle reaches position         z =   1.1750-111 m
#      time of flight is                 t =    3.501     ns
#      final momentum                    p =    3.975     MeV/c
#      final phase (cavity 1)      phi_end =    0.000     deg
#  --------------------------------------------------------------------------
#  off axis tracking of the reference particle:
#      initial position                  z =   -1.000     m
#                                        x =    0.000     mm
#                                        y =    0.000     mm
#
#      final position                    x =    112.5     mm
#                                        y =    0.000     mm
#      divergence                    px/pz =    1878.     mrad
#                                    py/pz =    0.000     mrad
#  --------------------------------------------------------------------------
#  tracking of        7 particles :
#      tracking will stop at             z =    0.000     m
#
#      space charge forces are EXCLUDED
#
#      working ...
#
#
#      final checkpoint at               z =  -1.3604E-08 m
#      total number of iteration steps:         11669
#
#      **********************************************************************
#
#      Particles taken into account      N =          7
#      total charge                      Q =    -7.0000E-02 nC
#      horizontal beam position          x =      112.5     mm
#      vertical beam position            y =      0.000     mm
#      longitudinal beam position        z =    -1.3604E-08 m
#      horizontal beam size          sig x =     0.4058     mm
#      vertical beam size            sig y =      0.000     mm
#      longitudinal beam size        sig z =     0.4550     mm
#      average kinetic energy            E =      3.497     MeV
#      energy spread                    dE =      21.18     keV
#      average momentum                  P =      3.975     MeV/c
#      transverse beam emittance     eps x =     5.5925E-02 pi mrad mm
#      correlated divergence         cor x =     -4.748     mrad
#      transverse beam emittance     eps y =      0.000     pi mrad mm
#      correlated divergence         cor y =      0.000     mrad
#      longitudinal beam emittance   eps z =     9.4872E-02 pi keV mm
#      correlated energy spread      cor z =      21.18     keV
#      emittance ratio eps y/eps x         =      0.000
#
#      Particle Statistics:
#
#
#      Total number of particles on stack     =          7
#      Electrons (total)                      =          7
#      particles at the cathode               =          0
#      active particles                       =          7
#      passive particles (lost out of bunch)  =          0
#      probe particles                        =          7
#      backward traveling particles           =          0
#      particles lost with z<Zmin             =          0
#      particles lost due to cathode field    =          0
#      particles lost on aperture             =          0
#
#      Tracking ended with     1 warning(s)
#
#
#      **********************************************************************
#
#      Ref. part. information saved to file   : Section1.ref.001
#      Trajectories saved to file             : Section1.track.001
#      Phase-space distributions logged in    : Section1.Log.001
#
#      **********************************************************************
#
#
#      finished simulation  15. 8.2026     21:45
#      execution time:  0.19 sek
#      Goodbye.
#  --------------------------------------------------------------------------
# Note: The following floating-point exceptions are signalling: IEEE_INVALID_FLAG IEEE_OVERFLOW_FLAG
#  --------------------------------------------------------------------------
#
#                      Astra- A space charge tracking algorithm
#                Version 4.0 - macOS 64bit - OpenMPI - Apple Silicon
#                               DESY,  Hamburg 2022
#                          15. 8.2026  21:45
#
#      Parameter file is:  Section2.in
#      90 degree bend section 2
#
#  Initialize element settings:
#      neglecting space charge forces
#
#  --------------------------------------------------------------------------
#  Cavity:
#
#      Reading cavity field data from:      3D_Dipole
#      Cavity Frequency               f =    0.000     GHz
#      3D magnetic field length             0.4500     m
#      Number of periods                      1
#      3D Section starts at                -6.0000E-02 m
#      3D Section ends at                   0.3900     m
#      maximum By field                     6.0312E-02 T
#      at                                   0.2600     m
#
#
#           WARNING: Switch to relative file name convention
#
#  --------------------------------------------------------------------------
#        7 particles from file Section1.0100.001
#
#      Particles taken into account      N =          7
#      total charge                      Q =    -7.0000E-02 nC
#      horizontal beam position          x =      112.5     mm
#      vertical beam position            y =      0.000     mm
#      longitudinal beam position        z =    -1.3604E-08 m
#      horizontal beam size          sig x =     0.4058     mm
#      vertical beam size            sig y =      0.000     mm
#      longitudinal beam size        sig z =     0.4550     mm
#      average kinetic energy            E =      3.497     MeV
#      energy spread                    dE =      21.18     keV
#      average momentum                  P =      3.975     MeV/c
#      transverse beam emittance     eps x =     5.5925E-02 pi mrad mm
#      correlated divergence         cor x =     -4.748     mrad
#      transverse beam emittance     eps y =      0.000     pi mrad mm
#      correlated divergence         cor y =      0.000     mrad
#      longitudinal beam emittance   eps z =     9.4872E-02 pi keV mm
#      correlated energy spread      cor z =      21.18     keV
#      emittance ratio eps y/eps x         =      0.000
#  --------------------------------------------------------------------------
#  on axis tracking of the reference particle:
#      initial position                  z =   2.8389E-06 m
#                                        x =    112.5     mm
#                                        y =    0.000     mm
#      initial momentum                  p =    3.975     MeV/c
#      global phase shift              phi =    0.000     deg
#      time step for integration        dt =   0.3000     ps
#  --------------------------------------------------------------------------
#  Online element settings:
#
#  --------------------------------------------------------------------------
#
#      particle reaches position         z =   0.5400     m
#      time of flight is                 t =    13.31     ns
#      final momentum                    p =    3.975     MeV/c
#      final phase (cavity 1)      phi_end =    0.000     deg
#  --------------------------------------------------------------------------
#  off axis tracking of the reference particle:
#      initial position                  z =   2.8389E-06 m
#                                        x =    112.9     mm
#                                        y =    0.000     mm
#
#      final position                    x =    3973.     mm
#                                        y =    0.000     mm
#      divergence                    px/pz =    7382.     mrad
#                                    py/pz =    0.000     mrad
#  --------------------------------------------------------------------------
#  tracking of        7 particles :
#      tracking will stop at             z =   0.5400     m
#
#      space charge forces are EXCLUDED
#
#      working ...
#
#
#      final checkpoint at               z =   0.5764     m
#      total number of iteration steps:         47459
#
#      **********************************************************************
#
#      Particles taken into account      N =          7
#      total charge                      Q =    -7.0000E-02 nC
#      horizontal beam position          x =      4036.     mm
#      vertical beam position            y =      0.000     mm
#      longitudinal beam position        z =     0.5400     m
#      horizontal beam size          sig x =      140.0     mm
#      vertical beam size            sig y =      0.000     mm
#      longitudinal beam size        sig z =      18.23     mm
#      average kinetic energy            E =      3.497     MeV
#      energy spread                    dE =      21.18     keV
#      average momentum                  P =      3.975     MeV/c
#      transverse beam emittance     eps x =      286.2     pi mrad mm
#      correlated divergence         cor x =     -35.72     mrad
#      transverse beam emittance     eps y =      0.000     pi mrad mm
#      correlated divergence         cor y =      0.000     mrad
#      longitudinal beam emittance   eps z =      2.790     pi keV mm
#      correlated energy spread      cor z =      21.18     keV
#      emittance ratio eps y/eps x         =      0.000
#
#      Particle Statistics:
#
#
#      Total number of particles on stack     =          7
#      Electrons (total)                      =          7
#      particles at the cathode               =          0
#      active particles                       =          7
#      passive particles (lost out of bunch)  =          0
#      probe particles                        =          7
#      backward traveling particles           =          0
#      particles lost with z<Zmin             =          0
#      particles lost due to cathode field    =          0
#      particles lost on aperture             =          0
#
#      Tracking ended with     1 warning(s)
#
#
#      **********************************************************************
#
#      Ref. part. information saved to file   : Section2.ref.001
#      Trajectories saved to file             : Section2.track.001
#      Phase-space distributions logged in    : Section2.Log.001
#
#      **********************************************************************
#
#
#      finished simulation  15. 8.2026     21:45
#      execution time:  0.72 sek
#      Goodbye.
#  --------------------------------------------------------------------------
# Note: The following floating-point exceptions are signalling: IEEE_INVALID_FLAG IEEE_OVERFLOW_FLAG
# 输出文件:
#    Section1.0100.001
#    Section1.Log.001
#    Section1.in
#    Section1.ref.001
#    Section1.track.001

# %%
# ===== 束团统计 (最后一个 z 位置) =====
from astra_tools.io import read_distribution
from astra_tools.analysis.statistics import compute_statistics, print_statistics
from astra_tools.widgets.panels import stats_table_html
ph = phase_files(work, STEM)
dist = read_distribution(ph[-1])
print("相空间文件:", ph[-1].name)
print_statistics(compute_statistics(dist),
                 title="%s @ %s" % (NAME, ph[-1].name))
stats_table_html(compute_statistics(dist))
# Out:
# 相空间文件: Section1.0100.001
#
# ================================================================
#   90deg_bend_Example @ Section1.0100.001
# ================================================================
#   Particles:              7 total,        7 active,      0 passive,
#                          0 lost,      0 not started
#   Total charge:        0.0700 nC (|Q| shown; sign kept internally)
# ----------------------------------------
#   Ref. momentum:       1.8680 MeV/c
#   Ref. kinetic E:      1.4256 MeV
#   gamma:               3.7899
#   beta:              0.964561
# ----------------------------------------
#   Centroid x:        112.4730 mm
#   Centroid y:          0.0000 mm
#   Centroid z:         -0.0000 mm
#   sigma_x:             0.4058 mm
#   sigma_y:             0.0000 mm
#   sigma_z:             0.4550 mm
# ----------------------------------------
#   Mean pz:             1.8680 MeV/c
#   sigma_p/p:         0.015409
#   Mean E_kin:          1.4256 MeV
#   sigma_E:            27.7626 keV
#   sigma_E/E:         0.019474
# ----------------------------------------
#   eps_x (geom):        0.0153 um.rad
#   eps_y (geom):        0.0000 um.rad
#   eps_nx:              0.0559 um.rad (= 0.0559 mm.mrad)
#   eps_ny:              0.0000 um.rad (= 0.0000 mm.mrad)
# ----------------------------------------
#   beta_x / alpha_x / gamma_T:  10.7639 m / 125.9404 / 1473.6260 1/m
#   beta_y / alpha_y / gamma_T:   0.0000 m /   0.0000 /   0.0000 1/m
# ================================================================
# <table style='border-collapse:collapse;font-family:monospace'><tr><th>quantity</th><th>value</th><th>unit</th></tr><tr><td>n_particle</td><td align='right'>7</td><td></td></tr>
# <tr><td>n_active</td><td align='right'>7</td><td></td></tr>
# <tr><td>n_passive</td><td align='right'>0</td><td></td></tr>
# <tr><td>n_lost</td><td align='right'>0</td><td></td></tr>
# <tr><td>n_not_started</td><td align='right'>0</td><td></td></tr>
# <tr><td>total_charge_nC</td><td align='right'>0.07 (|Q|)</td><td>nC</td></tr>
# <tr><td>mean_x_mm</td><td align='right'>112.473</td><td>mm</td></tr>
# <tr><td>mean_y_mm</td><td align='right'>0</td><td>mm</td></tr>
# <tr><td>mean_z_mm</td><td align='right'>-1.3604e-05</td><td>mm</td></tr>
# <tr><td>sig_x_mm</td><td align='right'>0.4058</td><td>mm</td></tr>
# <tr><td>sig_y_mm</td><td align='right'>0</td><td>mm</td></tr>
# <tr><td>sig_z_mm</td><td align='right'>0.454969</td><td>mm</td></tr>
# <tr><td>mean_pz_MeVc</td><td align='right'>1.86799</td><td>MeV/c</td></tr>
# <tr><td>sig_p_over_p_pct</td><td align='right'>1.54088</td><td>%</td></tr>
# <tr><td>mean_E_kin_MeV</td><td align='right'>1.42563</td><td>MeV</td></tr>
# <tr><td>sig_E_keV</td><td align='right'>27.7626</td><td>keV</td></tr>
# <tr><td>sig_E_over_E_pct</td><td align='right'>1.94738</td><td>%</td></tr>
# <tr><td>sig_xp_mrad</td><td align='right'>4.74811</td><td>mrad</td></tr>
# <tr><td>sig_yp_mrad</td><td align='right'>0</td><td>mrad</td></tr>
# <tr><td>emit_x_geom_um</td><td align='right'>0.0152987</td><td>um.rad</td></tr>
# <tr><td>emit_y_geom_um</td><td align='right'>0</td><td>um.rad</td></tr>
# <tr><td>emit_x_norm_um</td><td align='right'>0.0559255</td><td>um.rad</td></tr>
# <tr><td>emit_y_norm_um</td><td align='right'>0</td><td>um.rad</td></tr>
# <tr><td>emit_x_norm_mm_mrad</td><td align='right'>0.0559255</td><td>mm.mrad</td></tr>
# <tr><td>emit_y_norm_mm_mrad</td><td align='right'>0</td><td>mm.mrad</td></tr>
# <tr><td>beta_x_m</td><td align='right'>10.7639</td><td>m</td></tr>
# <tr><td>alpha_x</td><td align='right'>125.94</td><td>1</td></tr>
# <tr><td>gamma_t_x</td><td align='right'>1473.63</td><td>1/m</td></tr>
# <tr><td>beta_y_m</td><td align='right'>0</td><td>m</td></tr>
# <tr><td>alpha_y</td><td align='right'>0</td><td>1</td></tr>
# <tr><td>gamma_t_y</td><td align='right'>0</td><td>1/m</td></tr>
# <tr><td>ref_momentum_MeVc</td><td align='right'>1.868</td><td>MeV/c</td></tr>
# <tr><td>ref_kinetic_energy_MeV</td><td align='right'>1.42563</td><td>MeV</td></tr>
# <tr><td>gamma</td><td align='right'>3.78989</td><td>1</td></tr>
# <tr><td>beta_rel</td><td align='right'>0.964561</td><td>1</td></tr></table>

# %% [markdown]
# ### 教学要点
#
# 分段追踪: Section1 追踪到弯转入口, Section2 用 3D 二极场完成 90° 弯转。展示二极场截面与第一段的束团。

# %%
from astra_tools.plot.advanced_plots import plot_3d_map_slices
plot_3d_map_slices(work / "3D_Dipole.bx", axis="z", n_slices=3, unit="T")

# %%
from astra_tools.plot.phase_space import plot_phase_space
plot_phase_space(dist, plane="x")
plot_phase_space(dist, plane="z")

# %%
log = (work / "Section2.Log.001").read_text().splitlines()
print("Section2 Log 末尾:")
for ln in log[-12:]:
    print(ln)
# Out:
# Section2 Log 末尾:
#  STAT= 188*F,T,F,T,F,
#  T,F,T,F,T,F,
#  T,F,T,F,T,F,
#   198*T,
#  /
#  End of Input deck
# Section1.0100.001              -0.1360D-07  0.0000D+00  F
# Section2.0079.001               5.4000D-01  0.0000D+00  F
#
#      execution started:   15. 8.2026     21:45
#      execution finished:  15. 8.2026     21:45
#      execution time:  0.72 sek

# %%
# ===== 黄金比对 (rel < 0.5% 判 OK) =====
compare_xemit(NAME, work)
print("返回汇总: notebooks/06_examples.ipynb")
# Out:
#   末行比对 (new vs golden, log):
#     finished        True       True       OK
# 返回汇总: notebooks/06_examples.ipynb
