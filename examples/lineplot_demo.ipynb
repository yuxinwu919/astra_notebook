# %% [markdown]
# # lineplot 演化曲线专题
#
# 对应 04_lineplot.ipynb 的全部菜单: 九图 / t 轴变体 / 速度与步长 /
# 光学函数 / Sigma 特征发射度 / 真实 PScan 与 Scan / 稀有文件类型的
# 读法与画法 (合成示例数据, 明确标注)。

# %%
# %run ../notebooks/_bootstrap.py
# Out:
# astra-notebook 后端已加载 (v0.1.0)
# 项目根目录: /Users/yuxinwu/my_projects/astra_notebook
# 模拟工作目录: /Users/yuxinwu/my_projects/astra_notebook/data/workspace
# ASTRA    : /Users/yuxinwu/programs/ASTRA/astra
# Generator: /Users/yuxinwu/programs/ASTRA/generator

# %%
from examples._examples_spec import run_example
work = run_example("Manual_Example")
from astra_tools.io.astra_emit import read_emit_files, read_ref_file
emit = read_emit_files(str(work / "Example"))
ref = read_ref_file(str(work / "Example"))
from astra_tools.plot.emit_plots import plot_lineplot_overview
plot_lineplot_overview(emit)
# Out:
#  --------------------------------------------------------------------------
#
#                               generator
#                Version 1.0 - macOS 64bit - Apple Silicon
#                         DESY,  Hamburg 2002
#                         Mon Aug 17 01:17:09
#
#      Working File is:    generator.in
#      Initializing        500      electrons
#      including 6 probe particles at standard positions
#      Particles are quasi randomly distributed
#
#      Final check:
#      Particles taken into account      N =        500
#      total charge                      Q =     -1.000     nC
#      horizontal beam position          x =     2.9867E-04 mm
#      vertical beam position            y =     1.6453E-04 mm
#      longitudinal beam position        z =     8.5535E-08 m
#      horizontal beam size          sig x =     0.7499     mm
#      vertical beam size            sig y =     0.7499     mm
#      longitudinal beam size        sig z =     0.6595     mm
#      total emission time               t =     9.8937E-03 ns
#      rms emission time             sig t =      0.000     ns
#      average kinetic energy            E =      1000.     MeV
#      energy spread                    dE =      1.467     keV
#      average momentum                  P =      1001.     MeV/c
#      transverse beam emittance     eps x =      1.000     pi mrad mm
#      correlated divergence         cor x =     1.1244E-08 mrad
#      transverse beam emittance     eps y =      1.000     pi mrad mm
#      correlated divergence         cor y =     3.2174E-08 mrad
#      longitudinal beam emittance   eps z =     0.9672     pi keV mm
#      correlated energy spread      cor z =    -1.7272E-02 keV
#      emittance ratio eps y/eps x         =      1.000
#
#      phase-space distribution saved to file: Example.ini
#
#  --------------------------------------------------------------------------
#
#                      Astra- A space charge tracking algorithm
#                Version 4.0 - macOS 64bit - OpenMPI - Apple Silicon
#                               DESY,  Hamburg 2022
#                          17. 8.2026   1:17
#
#      Parameter file is:  Example.in
#      Example of ASTRA users manual
#
#  Initialize element settings:
#  --------------------------------------------------------------------------
#  Solenoid:
#
#      Reading solenoid field data from:    Solenoid.dat
#      field smoothing is applied
#      maximum |Bz| field                    0.3500     T
#      at                                     1.200     m
#      integral Bz squared                   1.7819E-02 T^2m
#
#  --------------------------------------------------------------------------
#      500 particles from file Example.ini
#
#      Particles taken into account      N =        500
#      total charge                      Q =     -1.000     nC
#      horizontal beam position          x =     2.9830E-04 mm
#      vertical beam position            y =     1.6413E-04 mm
#      longitudinal beam position        z =     8.5491E-08 m
#      horizontal beam size          sig x =     0.7499     mm
#      vertical beam size            sig y =     0.7499     mm
#      longitudinal beam size        sig z =     0.6595     mm
#      average kinetic energy            E =      1000.     MeV
#      energy spread                    dE =      1.467     keV
#      average momentum                  P =      1001.     MeV/c
#      transverse beam emittance     eps x =      1.000     pi mrad mm
#      correlated divergence         cor x =     1.0337E-08 mrad
#      transverse beam emittance     eps y =      1.000     pi mrad mm
#      correlated divergence         cor y =     3.1459E-08 mrad
#      longitudinal beam emittance   eps z =     0.9672     pi keV mm
#      correlated energy spread      cor z =    -1.7273E-02 keV
#      emittance ratio eps y/eps x         =      1.000
#  --------------------------------------------------------------------------
#      Start auto phasing:
#
#      Cavity phasing completed:
#      Cavity number   Energy gain [MeV]  at  Phase [deg]
#  --------------------------------------------------------------------------
#  on axis tracking of the reference particle:
#      initial position                  z =    0.000     m
#                                        x =    0.000     mm
#                                        y =    0.000     mm
#      initial momentum                  p =    1000.     MeV/c
#      global phase shift              phi =    0.000     deg
#      time step for integration        dt =    1.000     ps
#  --------------------------------------------------------------------------
#  Online element settings:
#
#  --------------------------------------------------------------------------
#
#      particle reaches position         z =    1.500     m
#      time of flight is                 t =    5.003     ns
#      final momentum                    p =    1000.     MeV/c
#      final phase (cavity 1)      phi_end =    0.000     deg
#  --------------------------------------------------------------------------
#  off axis tracking of the reference particle:
#      initial position                  z =    0.000     m
#                                        x =   0.7499     mm
#                                        y =   0.7499     mm
#
#      final position                    x =   0.7411     mm
#                                        y =   0.7585     mm
#      divergence                    px/pz =  -1.4328E-03 mrad
#                                    py/pz =   8.0707E-04 mrad
#  --------------------------------------------------------------------------
#  tracking of      500 particles :
#      tracking will stop at             z =    1.500     m
#
#      space charge forces are INCLUDED
#      cylindrical symmetric algorithm
#
#      working ...
# findfont: Failed to find font weight normal, now using 300.
# findfont: Failed to find font weight normal, now using 300.
# findfont: Failed to find font weight normal, now using 300.
#      final checkpoint at               z =    1.500     m
#      total number of iteration steps:          5012
#
#      **********************************************************************
#
#      Particles taken into account      N =        500
#      total charge                      Q =     -1.000     nC
#      horizontal beam position          x =     2.9703E-04 mm
#      vertical beam position            y =     1.6805E-04 mm
#      longitudinal beam position        z =      1.500     m
#      horizontal beam size          sig x =     0.7500     mm
#      vertical beam size            sig y =     0.7497     mm
#      longitudinal beam size        sig z =     0.6595     mm
#      average kinetic energy            E =      1000.     MeV
#      energy spread                    dE =      1.467     keV
#      average momentum                  P =      1001.     MeV/c
#      transverse beam emittance     eps x =      1.000     pi mrad mm
#      correlated divergence         cor x =    -2.9822E-04 mrad
#      transverse beam emittance     eps y =      1.003     pi mrad mm
#      correlated divergence         cor y =    -2.9778E-04 mrad
#      longitudinal beam emittance   eps z =     0.9673     pi keV mm
#      correlated energy spread      cor z =    -1.2630E-02 keV
#      emittance ratio eps y/eps x         =     0.9977
#
#      Particle Statistics:
#
#
#      Total number of particles on stack     =        500
#      Electrons (total)                      =        500
#      particles at the cathode               =          0
#      active particles                       =        500
#      passive particles (lost out of bunch)  =          0
#      probe particles                        =          6
#      backward traveling particles           =          0
#      particles lost with z<Zmin             =          0
#      particles lost due to cathode field    =          0
#      particles lost on aperture             =          0
#
#      **********************************************************************
#
#      Emittance information saved to file    : Example.Xemit.001
#      Emittance information saved to file    : Example.Yemit.001
#      Emittance information saved to file    : Example.Zemit.001
#      Ref. part. information saved to file   : Example.ref.001
#      Phase-space distributions logged in    : Example.Log.001
#      Sigma matrix saved to file             : Example.Sigma.001
#
#      **********************************************************************
#
#
#      finished simulation  17. 8.2026      1:17
#      execution time:  0.93 sek
#      Goodbye.
#  --------------------------------------------------------------------------
# Note: The following floating-point exceptions are signalling: IEEE_OVERFLOW_FLAG
# findfont: Failed to find font weight normal, now using 300.

# %%
from astra_tools.plot.emit_plots import (
    plot_envelope_evolution, plot_emittance_evolution,
    plot_velocity_evolution, plot_step_size_evolution)
plot_envelope_evolution(emit, x_axis="t")
plot_emittance_evolution(emit, x_axis="t")
plot_velocity_evolution(ref)
plot_step_size_evolution(ref)

# %%
from astra_tools.plot.advanced_plots import (
    plot_beta_alpha, plot_phase_advance, plot_coherence_length)
plot_beta_alpha(emit, ref=ref)
plot_phase_advance(emit, ref=ref)
plot_coherence_length(emit)
from astra_tools.io.astra_emit import read_sigma_file
from astra_tools.plot.emit_plots import plot_eigen_emittances
plot_eigen_emittances(read_sigma_file(str(work / "Example")))

# %%
# 真实 PScan / Scan (golden)
from astra_tools.io.astra_misc import read_pscan, read_scan, read_lab_file
from astra_tools.plot.advanced_plots import (
    plot_phase_scan, plot_pscan_dedz, plot_pscan_compression,
    plot_pscan_compression_time, plot_scan_fom, plot_scan_position)
pscan = read_pscan(
    PROJECT_ROOT / "examples/Cavity_Example/golden/astra.PScan.001")
plot_phase_scan(pscan)
plot_pscan_dedz(pscan)
plot_pscan_compression(pscan)
plot_pscan_compression_time(pscan)
scan = read_scan(PROJECT_ROOT / "examples/Manual_Example/Example.Scan.001")
lab = read_lab_file(
    PROJECT_ROOT / "examples/Manual_Example/golden/Example.lab.001")
plot_scan_fom(scan, i=0, lab=lab)
plot_scan_fom(scan, i=1, lab=lab)
plot_scan_position(scan)

# %% [markdown]
# ### 稀有文件类型 (合成示例数据)
#
# Xemit2/TRemit/Cemit/Larmor/Error/tcheck/LandF/track/Cathode 只有在
# deck 打开对应开关时 ASTRA 才输出; 这里用合成数据演示读法与画法,
# 真实文件换路径即可。

# %%
import numpy as np
from astra_tools.io.astra_emit import parse_output_file
z = np.linspace(0, 1.5, 20)
x2 = dict(z=z, K2z=np.zeros(20), K3z=np.zeros(20),
          eps_red_z=np.linspace(0.9e-6, 1e-6, 20),
          K2E=np.zeros(20), K3E=np.zeros(20),
          eps_red_zE=np.linspace(1.2e-6, 1.1e-6, 20))
tr = dict(z=z, eps_tr_x=np.linspace(1e-6, 1.1e-6, 20),
          eps_tr_y=np.linspace(1e-6, 0.9e-6, 20),
          eps_tr_z=np.linspace(1e-6, 1.2e-6, 20))
lm = dict(z=z, avr=np.linspace(0, 0.5, 20), rms=np.linspace(0.1, 0.3, 20))
tc = dict(z=z, scaling=np.random.default_rng(0).uniform(0.5, 1.5, (20, 5)),
          counter=np.arange(20))
err = dict(run=np.arange(30), z=np.full(30, 1.5),
           FOM=np.random.default_rng(1).normal(1e-6, 1e-8, (30, 10)))
landf = dict(landf_z=z, landf_n_particles=np.full(20, 500.0),
             landf_total_charge=np.full(20, 1e-9), landf_n_lost=np.zeros(20),
             landf_energy_deposited=np.linspace(0, 1e-4, 20),
             landf_energy_exchange=np.linspace(0, 2e-5, 20))
track = dict(seq=np.repeat([1, 2, 3], 20), status=np.ones(60, int),
             z=np.tile(z, 3), x=np.tile(np.linspace(0, 1e-3, 20), 3),
             y=np.tile(np.linspace(0, -0.5e-3, 20), 3),
             Ez=np.linspace(0, 1e6, 60), Er=np.linspace(1e5, 0, 60),
             Ey=np.linspace(0, 5e4, 60))
cathode = dict(t=np.linspace(0, 1e-9, 20), E_acc=np.linspace(5e6, 3e6, 20),
               E_spch=np.linspace(-2e6, 0, 20), q=np.linspace(0, 1e-3, 20))
crows = np.column_stack([z] + [np.full(20, v) for v in
    (1.0, 0.95, 0.9, 0.85, 1.0, 0.95, 0.9, 0.85, 5.0, 4.8, 4.5, 4.2)])
np.savetxt(SIM_DIR / "demo.Cemit.001", crows)
ce = parse_output_file(SIM_DIR / "demo.Cemit.001")
print("合成示例数据就绪")
# Out:
# 合成示例数据就绪

# %%
from astra_tools.plot.advanced_plots import (
    plot_reduced_emittance, plot_trace_emittance, plot_core_emittance,
    plot_core_brightness, plot_larmor, plot_error_hist, plot_tcheck_scaling,
    plot_losses, plot_beam_loading, plot_probe_trajectories,
    plot_space_charge_fields, plot_cathode_emission, plot_cr_emit)
plot_reduced_emittance(x2, x2)
plot_trace_emittance(tr)
plot_core_emittance(ce)
plot_core_emittance(ce, plane="z")
plot_core_brightness(ce, landf)
plot_larmor(lm)
plot_error_hist(err, i=0)
plot_tcheck_scaling(tc)
plot_losses(landf)
plot_beam_loading(landf)
plot_probe_trajectories(track)
plot_space_charge_fields(track)
plot_cathode_emission(cathode)
plot_cr_emit(dict(z=z, eps_x=np.full(20, 1e-6), eps_y=np.full(20, 1e-6),
                  q_rest=np.linspace(1, 0.8, 20),
                  q_cross=np.linspace(0, 0.2, 20)))
# Out:
# findfont: Failed to find font weight normal, now using 300.
